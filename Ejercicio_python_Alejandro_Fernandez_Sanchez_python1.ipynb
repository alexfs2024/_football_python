# %% [markdown]
# # Ejercicio de python
#
# Por favor, lee atentamente las siguientes indicaciones dado que **hay elementos que pueden restar puntos de la nota máxima**
#
# ## Formato de la entrega
# Se deberán entregar un único archivo con el nombre:
#  - Ejercicio-python-nombre-apellido1-apellido2.zip
#
# ## Contenido de la entrega
# -	El fichero requerido para la ejecución del código python (.ipynb) (recuerda que debe comprimise en un fichero zip, rar o equivalente) siguiendo las instrucciones indicadas en el apartado de arriba
#  - Deberá estar todo el código ejecutable para resolver el ejercicio.
#  - Es necesario rellenar al final el apartado de “conclusiones”. En esta celda solo habrá texto y será para que escribas las conclusiones del partido analizado
#
#
# ## A la hora de entregar:
# -	Asegúrate de completar todos los gráficos incluyendo un título acorde a la información que se muestra. La no inclusión de título supondrá una reducción de nota.
# -	Se proporciona una función con la cuál podrás pintar un campo de fútbol conforme a las medidas de Opta. (La encontrarás en la siguiente celda y se llama `pintar_campo`)
# - El fichero debe poder ejecutarse de principio a fin. Si al ejecutarlo desde el principio a final en el orden de las celdas hubiera algún fallo en la ejecución, no se podrá optar a la nota máxima. (Recomendamos que pruebes tu mismo la ejecución antes de hacer la entrega)
# -	Partes de la nota máxima: 100 puntos. Los fallos que tengas irán restando puntos de esta nota máxima.
#
#
# ## Enunciado
# En este ejercicio vamos a analizar, gracias a los datos proporcionados por Opta, algunos elementos de la temporada 2020-2021 de LaLiga y haremos también una pequeña parte de análisis de un partido concreto de fútbol. En los ejercicios 5 y 10 encontrarás información relevante para resolver mejor este ejercicio.
#
# Con el fin de analizar algunos datos te indicamos la siguiente información. La columna llamada type_id contiene información de los diferentes tipos de eventos. Los goles corresponden a los valores de type_id == 16. Las tarjetas corresponden a los valores de type_id==17. Dicho de otro modo, en las filas en las que el type_id valga 16 corresponderán a los goles y las filas en las que el type_id tenga valor 17 corresponderán a las tarjetas
#
#
# ## Ejercicios a completar
#
#  - Renombra el notebook para que se llamen nombre_apellido1_apellido2_python.ipynb
#  - Muestra el **ranking de goleadores** de la liga.  (solo interesa ver el nombre-apellidos del jugador y el número de goles, mostrar más datos reducirá la nota)
#  - Muestra el **ranking de equipos con más tarjetas**. (solo interesa ver el nombre del equipo y número de tarjetas, mostrar más datos reducirá la nota)
#  - Crea un **diagrama de barras** en el que se indiquen los goles marcados por cada tipo de `real_position`. (Comprueba que los valores de la gráfica coinciden con los datos que hay)
#  - Crea un **gráfico de barra**s en el que se muestra el número de tarjetas que ha visto cada tipo de `real_position`. (Comprueba que los valores de la gráfica coinciden con los datos que hay)
#  - Representa en el mismo campo de fútbol, pero con diferentes colores, la posición desde la que han marcado todos los **goles de la temporada Karim Benzema y Lionel Messi**.
#  - Selecciona todos los datos de eventos del partido Atlético de Madrid – Cádiz CF  de fecha 31-enero-2021. (Desde este momento todas las preguntas serán relativas a este partido en concreto. Es decir, no uses el dataset completo para responder a las preguntas que vienen a continuación porque el resultado será el equivocado)
#    - Muestra cuántos eventos hay para el partido seleccionado
#    - Muestra la información de los goles del partido teniendo en cuenta que tan solo se quiere ver la información de: equipo, jugador, minuto en el que se marcó (mostrar más datos de los solicitados reducirá la nota)
#    - Representa en un campo de fútbol la posición desde la que se han marcado los goles.
#    - Sabiendo que la longitud del campo es 100m. Calcula el valor (en metros) de la distancia del gol más alejado de la portería. (Para el cálculo de la distancia a portería usaremos únicamente el valor horizontal de la posición). El resultado de este ejercicio debe ser un número que corresponda a la distancia
#    - Calcula la posición media de cada uno de los jugadores del Atlético de Madrid que hayan participado partido del 31-enero-2021. (El resultado debe tener la posición (x,y) de todos los jugadores que hayan participado en el partido.
#    - Representa en un campo de futbol la posición media de los jugadores del Atlético de Madrid calculada en el ejercicio anterior y correspondientes al partido de 31-enero-2021 (El resultado debe tener la posición (x,y) de todos los jugadores que hayan participado en el partido.
#    - Calcula para el Cádiz el porcentaje de eventos que ha generado en cada una de las siguientes zonas para los eventos del partido de 31-enero-2021:
#        *  x <= 17 (zona1)
#        * x > 17 y x <=50 (zona2)
#        *  x>50 y x <=83 (zona3)
#        * x>83 (zona4).
#
#        El orden para mostrar el resultado debe estar ordenado de zona1, zona2, zona3 a zona4  (usa un filtrado de columnas para obtener el resultado ordenado). No cambies los valores de los filtros para no tener resultados diferentes que puedan ver reducida la nota. No alteres el orden de los resultados.
#    - Calcula para el Atlético de Madrid el porcentaje de eventos que ha generado en cada una de las siguientes zonas para los eventos del partido de 31-enero-2021:
#        *  x <= 17 (zona1)
#        * x > 17 y x <=50 (zona2)
#        *  x>50 y x <=83 (zona3)
#        * x>83 (zona4).
#
#        El orden para mostrar el resultado debe estar ordenado de zona1, zona2, zona3 a zona4  (usa un filtrado de columnas para obtener el resultado ordenado). No cambies los valores de los filtros para no tener resultados diferentes que puedan ver reducida la nota. No alteres el orden de los resultados.
#    - Representa en un campo de futbol los eventos en los que participó Luis Suárez en el partido de 31 enero 2021 usando colores diferentes para marcar las diferentes zonas en las que ocurrieron.
#    - Usando los datos del partido seleccionado (31 enero 2021) realiza un análisis a tu elección sobre algún punto que consideres relevante.
#    - Conclusiones: A la vista de los resultados del análisis escribe tus conclusiones sobre cada uno de los siguientes puntos:
#        - Raking goleadores
#        - Ranking equipos con más tarjetas
#        - Posición media de cada jugador del ATM
#        - Porcentajes de eventos por zonas del ATM
#        - Porcentajes de eventos por zonas del CAD

# %%
# Usa la siguiente función para pintar el campo de fútbol

# %%
def pintar_campo(color_campo):
    """Usa esta función como referente para pintar el campo de fútbol"""
    ax = plt.axes()
    bottom, width, lenght= 0., 100, 100

    pitch_width, pitch_length=68., 105

    goal_width, goal_length, goal_bottom, goal_top =10.76, 1.9, 44.62, 55.38

    six_yard_width, six_yard_length, six_yard_left =26.4, 5.8, 5.8

    six_yard_right, six_yard_bottom, six_yard_top=94.2, 36.8, 63.2

    penalty_left, penalty_right=11.5, 88.5
    penalty_area_width, penalty_area_length, penalty_area_left=57.8 ,17.0, 17.

    penalty_area_right, penalty_area_bottom, penalty_area_top=83., 21.1, 78.9

    center_width, center_length, circle_diameter=50., 50, 17.68

    coord_x = [center_length, center_length, width, width,
                  penalty_area_right, penalty_area_right, width,
                  width, six_yard_right, six_yard_right, width,
                  width, bottom, bottom, penalty_area_left,
                  penalty_area_left, bottom, bottom, six_yard_left,
                  six_yard_left, bottom, bottom, center_length, ]
    coord_y = [bottom, lenght, lenght, penalty_area_bottom,
                  penalty_area_bottom, penalty_area_top, penalty_area_top,
                  six_yard_bottom, six_yard_bottom, six_yard_top,
                  six_yard_top, bottom, bottom, penalty_area_top,
                  penalty_area_top, penalty_area_bottom, penalty_area_bottom,
                  six_yard_top, six_yard_top, six_yard_bottom,
                  six_yard_bottom, lenght, lenght, ]

    plt.plot(coord_x, coord_y, color_campo)
    circulo_central = plt.Circle((50,50), radius=10, fill=False, color=color_campo)
    ax.add_patch(circulo_central)

    circulo_central = plt.Circle((50, 50), radius=.5, fill=True, color=color_campo)
    ax.add_patch(circulo_central)

    punto_penalti1 = plt.Circle((11, 50), radius=.5, fill=True, color=color_campo)
    ax.add_patch(punto_penalti1)

    punto_penalti2 = plt.Circle((89, 50), radius=.5, fill=True, color=color_campo)
    ax.add_patch(punto_penalti2)

    arq_izq = Arc((11,50),20, 20,theta1=310,theta2=50,color=color_campo)
    arq_dcho = Arc((89,50),20,20,theta1=130,theta2=230,color=color_campo)
    ax.add_patch(arq_izq)
    ax.add_patch(arq_dcho)


    plt.plot(coord_x, coord_y, color_campo)
    return ax

# %% [markdown]
# # Importa las librerías y el fichero.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib; matplotlib.style.use('ggplot')
from matplotlib.patches import Arc, Circle
sns.set_context("notebook")
sns.set_palette('husl')

# %%
df=pd.read_csv('/content/drive/MyDrive/CURSO PYTHON/MOD 4/Tarea Python/eventos_2020_2021.csv')
df
# Out:
#         type_id                timestamp     x     y real_position  \
# 0             1  2020-09-13T13:01:48.321  49.9  50.1       Striker
# 1             1  2020-09-13T13:02:48.939  68.2  80.6       Striker
# 2             1  2020-09-13T13:05:53.611  99.5  99.5       Striker
# 3             3  2020-09-13T13:08:39.214  62.3  89.9       Striker
# 4             1  2020-09-13T13:08:42.286  60.2  92.4       Striker
# ...         ...                      ...   ...   ...           ...
# 654693        1  2021-05-22T18:27:42.899   3.2  49.9    Goalkeeper
# 654694        1  2021-05-22T18:40:35.891   4.8  55.1    Goalkeeper
# 654695        1  2021-05-22T18:45:33.690   4.8  56.9    Goalkeeper
# 654696       52  2021-05-22T18:51:08.560   9.7  47.0    Goalkeeper
# 654697        1  2021-05-22T18:51:11.107  10.2  46.7    Goalkeeper
#
#                player           team  year  month  day
# 0         Lucas Pérez         Alaves  2020      9   13
# ...

# %%
df.columns
# Out:
# Index(['type_id', 'timestamp', 'x', 'y', 'real_position', 'player', 'team',
#        'year', 'month', 'day'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 654698 entries, 0 to 654697
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   type_id        654698 non-null  int64
#  1   timestamp      654698 non-null  object
#  2   x              654698 non-null  float64
#  3   y              654698 non-null  float64
#  4   real_position  654698 non-null  object
#  5   player         654698 non-null  object
#  6   team           654698 non-null  object
#  7   year           654698 non-null  int64
#  8   month          654698 non-null  int64
#  9   day            654698 non-null  int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 49.9+ MB

# %% [markdown]
# # 1. Ranking de goles
# El ranking de goles es el listado de mayor a menor del total de goles marcados por cada jugador
#
# (solo interesa ver el nombre-apellidos del jugador y el número de goles, mostrar más datos reducirá la nota)

# %%
goals_rank = df[df['type_id'] == 16]['player'].value_counts()
goals_rank
# Out:
# Lionel Messi         30
# Luis Suárez          26
# Karim Benzema        23
# Gerard Moreno        23
# Youssef En-Nesyri    18
#                      ..
# Bruno González        1
# Stefan Savic          1
# Rubén Sobrino         1
# Sergio Postigo        1
# Denis Vavro           1
# Name: player, Length: 273, dtype: int64

# %% [markdown]
# # 2. Ranking de tarjetas por equipos
# El ranking de tarjetas es el listado de mayor a menor del total de tarjetas que tiene cada equipo
#
# (solo interesa ver el nombre del equipo y número de tarjetas, mostrar más datos reducirá la nota)

# %%
card_rank=df[df['type_id'] == 17]['team'].value_counts()
card_rank
# Out:
# Getafe                126
# Celta de Vigo         107
# Granada CF            103
# Atletico de Madrid     98
# Alaves                 96
# Real Valladolid        95
# Real Betis             95
# Elche CF               93
# Athletic Club          85
# Real Sociedad          82
# Valencia CF            82
# Cadiz CF               82
# C.A. Osasuna           82
# Sevilla                79
# Barcelona              72
# Villarreal             71
# Levante                70
# Huesca                 69
# Eibar                  67
# Real Madrid            60
# Name: team, dtype: int64

# %% [markdown]
# # 3. Crea un **diagrama de barras** en el que se indiquen los goles marcados por cada tipo de `real_position`.
# (Comprueba que los valores de la gráfica coinciden con los datos que hay)

# %% [markdown]
# Ejercicio 5

# %%
posiciones=df[df['type_id'] == 16]['real_position'].value_counts()
posiciones
# Out:
# Striker                 351
# Winger                  156
# Attacking Midfielder     98
# Second Striker           96
# Central Midfielder       92
# Central Defender         78
# Full Back                45
# Defensive Midfielder     14
# Goalkeeper                4
# Wing Back                 1
# Unknown                   1
# Name: real_position, dtype: int64

# %%
df_2=df[df.type_id == 16]
df_2.head(5)
# Out:
#       type_id                timestamp     x     y         real_position  \
# 267        16  2020-11-08T17:34:09.664  88.0  62.7               Striker
# 332        16  2020-11-22T20:16:33.962  88.5  50.1               Striker
# 372        16  2020-11-28T20:08:23.746  88.6  50.1               Striker
# 584        16  2020-12-31T16:51:53.334  88.5  50.0               Striker
# 2895       16  2021-04-18T16:55:22.658  82.9  53.0  Defensive Midfielder
#
#                  player    team  year  month  day
# 267         Lucas Pérez  Alaves  2020     11    8
# 332         Lucas Pérez  Alaves  2020     11   22
# 372         Lucas Pérez  Alaves  2020     11   28
# 584         Lucas Pérez  Alaves  2020     12   31
# 2895  Rodrigo Battaglia  Alaves  2021      4   18

# %%
sns_plot = sns.catplot(x='real_position', data=df_2, kind="count", height=5,
                          aspect=3, edgecolor='black');
real_position = ['Striker','Defensive Midfielder','Central Defender','Winger','Central Midfielder','Full Back','Attacking Midfielder','Second Striker',
             'Goalkeeper','Wing Back','Unknown']
sns_plot.set_xticklabels(real_position)
sns_plot.fig.suptitle("Goles por Posiciones")
sns_plot.set_ylabels("Número de Goles")
sns_plot.set_xlabels("Posición")

ax = plt.gca()

# Añadir texto a cada columna
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(),
            '{0}'.format(int(p.get_height())),
            fontsize=10, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # 4. Crea un **gráfico de barra**s en el que se muestra el número de tarjetas que ha visto cada tipo de `real_position`.
# (Comprueba que los valores de la gráfica coinciden con los datos que hay)

# %%
numero_tarjetas=df[df['type_id'] == 17]['real_position'].value_counts()
numero_tarjetas
# Out:
# Central Defender        407
# Central Midfielder      291
# Full Back               289
# Striker                 193
# Winger                  168
# Attacking Midfielder    144
# Defensive Midfielder    129
# Goalkeeper               34
# Second Striker           34
# Wing Back                15
# Unknown                  10
# Name: real_position, dtype: int64

# %%
df_3=df[df.type_id == 17]
df_3.head(5)
# Out:
#       type_id                timestamp    x    y         real_position  \
# 932        17  2021-02-27T19:09:56.475  0.0  0.0               Striker
# 1369       17  2020-09-20T17:57:34.455  0.0  0.0  Defensive Midfielder
# 1451       17  2020-09-26T13:22:33.726  0.0  0.0  Defensive Midfielder
# 1820       17  2020-11-08T19:03:55.661  0.0  0.0  Defensive Midfielder
# 1974       17  2020-12-06T21:18:21.925  0.0  0.0  Defensive Midfielder
#
#                  player    team  year  month  day
# 932         Lucas Pérez  Alaves  2021      2   27
# 1369  Rodrigo Battaglia  Alaves  2020      9   20
# 1451  Rodrigo Battaglia  Alaves  2020      9   26
# 1820  Rodrigo Battaglia  Alaves  2020     11    8
# 1974  Rodrigo Battaglia  Alaves  2020     12    6

# %%
sns_plot = sns.catplot(x='real_position', data=df_3, kind="count", height=5,
                          aspect=3, edgecolor='black');
real_position = ['Striker','Defensive Midfielder','Central Defender','Second Striker','Winger','Central Midfielder','Full Back','Attacking Midfielder','Wing Back',
             'Goalkeeper','Unknown']
sns_plot.set_xticklabels(real_position)
sns_plot.fig.suptitle("Goles por Posiciones")
sns_plot.set_ylabels("Número de Goles")
sns_plot.set_xlabels("Posición")

ax = plt.gca()

# Añadir texto a cada columna
for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2., p.get_height(),
            '{0}'.format(int(p.get_height())),
            fontsize=10, color='black', ha='center', va='bottom')
plt.show()

# %% [markdown]
# # 5. Representa en el mismo campo de fútbol, pero con diferentes colores, la posición desde la que han marcado todos los **goles de la temporada Karim Benzema y Lionel Messi**.

# %% [markdown]
# Visualización de eventos de opta

# %%
df_2['player']
# Out:
# 267                    Lucas Pérez
# 332                    Lucas Pérez
# 372                    Lucas Pérez
# 584                    Lucas Pérez
# 2895             Rodrigo Battaglia
#                     ...
# 645896            Facundo Ferreyra
# 646222    Moriba Kourouma Kourouma
# 648387              Domingos Quina
# 648459              Domingos Quina
# 650386                 Denis Vavro
# Name: player, Length: 936, dtype: object

# %%
jugadores_interesantes = ['Karim Benzema', 'Lionel Messi']
df_goles_messi_benzema=df_2[df_2['player'].isin(jugadores_interesantes)]
df_goles_messi_benzema.head(5)
# Out:
#         type_id                timestamp     x     y   real_position  \
# 125092       16  2021-02-24T19:03:52.464  92.0  48.6  Second Striker
# 125125       16  2021-02-24T19:24:46.763  95.0  52.4  Second Striker
# 125184       16  2021-01-06T20:39:47.157  85.3  65.8  Second Striker
# 125221       16  2021-01-06T21:21:17.013  92.1  58.1  Second Striker
# 125297       16  2020-09-27T20:34:44.111  88.5  50.0  Second Striker
#
#               player       team  year  month  day
# 125092  Lionel Messi  Barcelona  2021      2   24
# 125125  Lionel Messi  Barcelona  2021      2   24
# 125184  Lionel Messi  Barcelona  2021      1    6
# 125221  Lionel Messi  Barcelona  2021      1    6
# 125297  Lionel Messi  Barcelona  2020      9   27

# %%
df_goles_messi_benzema = df_goles_messi_benzema.set_index(['player'])

ax = pintar_campo('grey')


df_goles_messi_benzema.loc['Lionel Messi'].plot(kind='scatter', x='x', y='y', color='blue', ax=ax)
df_goles_messi_benzema.loc['Karim Benzema'].plot(kind='scatter', x='x', y='y', color='orange', ax=ax)

ax.set_title("Lugar desde donde marcan los goles Karim Benzema y Lionel Messi",
             fontsize=15);

# %% [markdown]
# # 6. Selecciona todos los datos de eventos del partido Atlético de Madrid – Cádiz CF  de fecha 31-enero-2021.
# (Desde este momento todas las preguntas serán relativas a este partido en concreto. Es decir, no uses el dataset completo para responder a las preguntas que vienen a continuación porque el resultado será el equivocado)

# %%
partido= df[((df['team'] == 'Atletico de Madrid') | (df['team'] == 'Cadiz CF')) & (df['month'] == 1) & (df['day'] == 31)]

# %%
partido.head()
# Out:
#        type_id                timestamp     x     y real_position  \
# 44990       67  2021-01-31T15:25:30.253  75.4  50.6       Striker
# 44991        1  2021-01-31T15:25:30.262  76.4  48.7       Striker
# 44992        1  2021-01-31T15:26:48.440  33.6   4.0       Striker
# 44993        1  2021-01-31T15:26:50.742  35.1   1.3       Striker
# 44994        1  2021-01-31T15:27:09.878  67.0  37.1       Striker
#
#             player                team  year  month  day
# 44990  Luis Suárez  Atletico de Madrid  2021      1   31
# 44991  Luis Suárez  Atletico de Madrid  2021      1   31
# 44992  Luis Suárez  Atletico de Madrid  2021      1   31
# 44993  Luis Suárez  Atletico de Madrid  2021      1   31
# 44994  Luis Suárez  Atletico de Madrid  2021      1   31

# %%
partido.tail()
# Out:
#         type_id                timestamp     x     y real_position  \
# 644613        1  2021-01-31T17:01:08.314  62.7  21.0       Striker
# 644614        1  2021-01-31T17:02:19.330  65.9  41.2       Striker
# 644615       44  2021-01-31T17:02:45.817  87.7  44.6       Striker
# 644616       61  2021-01-31T17:02:45.954  87.6  43.9       Striker
# 644617       50  2021-01-31T17:10:00.078  68.4  46.6       Striker
#
#                player      team  year  month  day
# 644613  Ivan Saponjic  Cadiz CF  2021      1   31
# 644614  Ivan Saponjic  Cadiz CF  2021      1   31
# 644615  Ivan Saponjic  Cadiz CF  2021      1   31
# 644616  Ivan Saponjic  Cadiz CF  2021      1   31
# 644617  Ivan Saponjic  Cadiz CF  2021      1   31

# %%
partido.columns
# Out:
# Index(['type_id', 'timestamp', 'x', 'y', 'real_position', 'player', 'team',
#        'year', 'month', 'day'],
#       dtype='object')

# %% [markdown]
# # 6 bis. Muestra cuántos eventos hay para el partido seleccionado

# %%
partido.shape
# Out:
# (1804, 10)

# %% [markdown]
# # 7. Muestra la información de los goles del partido teniendo en cuenta que tan solo se quiere ver la información de: equipo, jugador, minuto en el que se marcó
# (mostrar más datos de los solicitados reducirá la nota)

# %%
mask=partido['type_id']==16
partido[mask][['timestamp','player','team']]
# Out:
#                       timestamp              player                team
# 45000   2021-01-31T15:43:46.086         Luis Suárez  Atletico de Madrid
# 45014   2021-01-31T16:28:17.643         Luis Suárez  Atletico de Madrid
# 47574   2021-01-31T17:05:55.413  Jorge Resurrección  Atletico de Madrid
# 100067  2021-01-31T16:00:23.295         Saúl Ñíguez  Atletico de Madrid
# 226639  2021-01-31T15:50:30.693      Álvaro Negredo            Cadiz CF
# 226668  2021-01-31T16:49:04.930      Álvaro Negredo            Cadiz CF

# %% [markdown]
# # 8. Representa en un campo de fútbol la posición desde la que se han marcado los goles.

# %%
partido_2=partido[partido['type_id']==16]
partido_2
# Out:
#         type_id                timestamp     x     y       real_position  \
# 45000        16  2021-01-31T15:43:46.086  74.2  57.3             Striker
# 45014        16  2021-01-31T16:28:17.643  88.5  50.0             Striker
# 47574        16  2021-01-31T17:05:55.413  90.5  54.2  Central Midfielder
# 100067       16  2021-01-31T16:00:23.295  92.4  42.1  Central Midfielder
# 226639       16  2021-01-31T15:50:30.693  84.9  27.4             Striker
# 226668       16  2021-01-31T16:49:04.930  90.5  51.0             Striker
#
#                     player                team  year  month  day
# 45000          Luis Suárez  Atletico de Madrid  2021      1   31
# 45014          Luis Suárez  Atletico de Madrid  2021      1   31
# 47574   Jorge Resurrección  Atletico de Madrid  2021      1   31
# 100067         Saúl Ñíguez  Atletico de Madrid  2021      1   31
# 226639      Álvaro Negredo            Cadiz CF  2021      1   31
# 226668      Álvaro Negredo            Cadiz CF  2021      1   31

# %%
partido_2.columns
# Out:
# Index(['type_id', 'timestamp', 'x', 'y', 'real_position', 'player', 'team',
#        'year', 'month', 'day'],
#       dtype='object')

# %%
ax = pintar_campo('grey')
partido_2[partido_2['player'] == 'Luis Suárez'].plot(kind='scatter', x='x', y='y', color='blue', ax=ax)
partido_2[partido_2['player'] == 'Álvaro Negredo'].plot(kind='scatter', x='x', y='y', color='yellow', ax=ax)
partido_2[partido_2['player'] == 'Jorge Resurrección'].plot(kind='scatter', x='x', y='y', color='green', ax=ax)
partido_2[partido_2['player'] == 'Saúl Ñíguez'].plot(kind='scatter', x='x', y='y', color='red', ax=ax)

ax.set_title("Posición de los goles",
             fontsize=15);

# %% [markdown]
# # 9. Sabiendo que la longitud del campo es 100m. Calcula el valor (en metros) de la distancia del gol más alejado de la portería.
# (Para el cálculo de la distancia a portería usaremos únicamente el valor horizontal de la posición).
#
# El resultado de este ejercicio debe ser un número que corresponda a la distancia.
#
# El cálculo no puede "hacerse a mano". Es decir, no vale código que se parezca a esto:
# ```
# 100 - 60 = 40m
# ```

# %%
porteria=100
distancia_lanzamiento=74.2
print(f"Distancia gol mas alejado: {porteria-distancia_lanzamiento}")
# Out:
# Distancia gol mas alejado: 25.799999999999997

# %% [markdown]
# # 10. Calcula la posición media de cada uno de los jugadores del Atlético de Madrid que hayan participado partido del 31-enero-2021.
# (El resultado debe tener la posición (x,y) de todos los jugadores que hayan participado en el partido.

# %% [markdown]
# Ejercicio de agrupaciones

# %% [markdown]
# 1- Filtrar solo jugadores del atletico del df : 'partido'
# 2-

# %%
equipo_A= partido[partido['team'] == 'Atletico de Madrid']
equipo_A.head(5)
# Out:
#        type_id                timestamp     x     y real_position  \
# 44990       67  2021-01-31T15:25:30.253  75.4  50.6       Striker
# 44991        1  2021-01-31T15:25:30.262  76.4  48.7       Striker
# 44992        1  2021-01-31T15:26:48.440  33.6   4.0       Striker
# 44993        1  2021-01-31T15:26:50.742  35.1   1.3       Striker
# 44994        1  2021-01-31T15:27:09.878  67.0  37.1       Striker
#
#             player                team  year  month  day
# 44990  Luis Suárez  Atletico de Madrid  2021      1   31
# 44991  Luis Suárez  Atletico de Madrid  2021      1   31
# 44992  Luis Suárez  Atletico de Madrid  2021      1   31
# 44993  Luis Suárez  Atletico de Madrid  2021      1   31
# 44994  Luis Suárez  Atletico de Madrid  2021      1   31

# %%
atm= equipo_A.groupby('player')[['x', 'y']].mean().round(2)
atm
# Out:
#                                         x      y
# player
# Felipe Augusto de Almeida Monteiro  31.35  63.85
# Geoffrey Kondogbia                  18.24  41.33
# Héctor Herrera                      35.35  42.45
# Jan Oblak                            9.45  47.56
# Jorge Resurrección                  42.25  40.25
# José Giménez                        31.91  62.26
# João Félix Sequeira                 64.20  31.75
# Lucas Torreira                      44.69  56.86
# Luis Suárez                         61.52  49.62
# Marcos Llorente                     45.21  21.95
# Renan Augusto Lodi dos Santos       33.55  84.60
# Saúl Ñíguez                         46.22  74.04
# Sime Vrsaljko                       43.34   8.08
# Stefan Savic                        31.92  18.77
# Thomas Lemar                        50.92  66.94
# Ángel Correa                        46.30  21.33

# %% [markdown]
# # 11. Representa en un campo de futbol la posición media de los jugadores del Atlético de Madrid calculada en el ejercicio anterior y correspondientes al partido de 31-enero-2021
# (El resultado debe tener la posición (x,y) de todos los jugadores que hayan participado en el partido representado como un punto en una imagen

# %%
ax = pintar_campo('grey')
atm.plot(kind='scatter', x='x', y='y', color='red', marker='X', s=100, ax=ax)
ax.set_title("Posición media de todos los jugadores",
             fontsize=15)

plt.show()

# %% [markdown]
# ## 12. Calcula para el Cádiz el porcentaje de eventos que ha generado en cada una de las siguientes zonas para los eventos del partido de 31-enero-2021:
# Zonas:
#  - x <= 17 (zona1)
#  - x > 17 y x <=50 (zona2)
#  - x>50 y x <=83 (zona3)
#  - x>83 (zona4).
#
# El orden para mostrar el resultado debe estar ordenado de zona1, zona2, zona3 a zona4
# Usa un filtrado de columnas para obtener el resultado ordenado.
#
# No cambies los valores de los filtros para no tener resultados diferentes que puedan ver reducida la nota. No alteres el orden de los resultados.

# %% [markdown]
# MANEJO DE DATA FRAMES.

# %%
equipo_B= partido[partido['team'] == 'Cadiz CF']
equipo_B.head(5)
# Out:
#         type_id                timestamp     x     y     real_position  \
# 215802        1  2021-01-31T15:16:28.598  29.9  53.3  Central Defender
# 215803        1  2021-01-31T15:16:41.813  34.2  62.6  Central Defender
# 215804        1  2021-01-31T15:18:56.254  54.2  96.3  Central Defender
# 215805       67  2021-01-31T15:19:38.037  34.8  69.7  Central Defender
# 215806        8  2021-01-31T15:19:38.041  33.8  76.4  Central Defender
#
#                   player      team  year  month  day
# 215802  Juan Torres Ruiz  Cadiz CF  2021      1   31
# 215803  Juan Torres Ruiz  Cadiz CF  2021      1   31
# 215804  Juan Torres Ruiz  Cadiz CF  2021      1   31
# 215805  Juan Torres Ruiz  Cadiz CF  2021      1   31
# 215806  Juan Torres Ruiz  Cadiz CF  2021      1   31

# %%
equipo_B.shape
# Out:
# (874, 10)

# %%
for i in range(len(equipo_B)):

  if equipo_B.x.values[i] <= 17:
    equipo_B.loc[i,'clasificacion'] = 'zona 1'

  elif (equipo_B.x.values[i]  > 17) & (equipo_B.x.values[i]  <= 50):
    equipo_B.loc[i,'clasificacion']= 'zona 2'
  elif(equipo_B.x.values[i]  > 50) & (equipo_B.x.values[i]  <= 83):
    equipo_B.loc[i,'clasificacion']= 'zona 3'

  else :
    equipo_B.loc[i,'clasificacion'] = 'zona 4'
# Out:
# <ipython-input-238-b2933c72190b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   equipo_B.loc[i,'clasificacion']= 'zona 2'

# %%
equipo_B.clasificacion.value_counts()
# Out:
# zona 3    386
# zona 2    274
# zona 1    139
# zona 4     75
# Name: clasificacion, dtype: int64

# %%
zona1=139
zona2=274
zona3=386
zona4=75
total=874
print(f"% Zona 1: {((zona1/total)*100)}")
print(f"% Zona 2: {((zona2/total)*100)}")
print(f"% Zona 3: {((zona3/total)*100)}")
print(f"% Zona 4: {((zona4/total)*100)}")
# Out:
# % Zona 1: 15.903890160183066
# % Zona 2: 31.35011441647597
# % Zona 3: 44.16475972540046
# % Zona 4: 8.581235697940503

# %% [markdown]
# ## 13. Calcula para el Atlético de Madrid el porcentaje de eventos que ha generado en cada una de las siguientes zonas  para los eventos del partido de 31-enero-2021:
#
# Zonas:
#  - x <= 17 (zona1)
#  - x > 17 y x <=50 (zona2)
#  - x>50 y x <=83 (zona3)
#  - x>83 (zona4).
#
# El orden para mostrar el resultado debe estar ordenado de zona1, zona2, zona3 a zona4
# Usa un filtrado de columnas para obtener el resultado ordenado.
#
# No cambies los valores de los filtros para no tener resultados diferentes que puedan ver reducida la nota. No alteres el orden de los resultados.

# %%
equipo_A.shape
# Out:
# (930, 10)

# %%
for i in range(len(equipo_A)):

  if equipo_A.x.values[i] <= 17:
    equipo_A.loc[i,'clasificacion'] = 'zona 1'

  elif (equipo_A.x.values[i]  > 17) & (equipo_A.x.values[i]  <= 50):
    equipo_A.loc[i,'clasificacion']= 'zona 2'
  elif(equipo_A.x.values[i]  > 50) & (equipo_A.x.values[i]  <= 83):
    equipo_A.loc[i,'clasificacion']= 'zona 3'

  else :
    equipo_A.loc[i,'clasificacion'] = 'zona 4'
# Out:
# <ipython-input-242-a19e66e0c53a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   equipo_A.loc[i,'clasificacion']= 'zona 3'

# %%
equipo_A.clasificacion.value_counts()
# Out:
# zona 2    432
# zona 3    256
# zona 1    179
# zona 4     63
# Name: clasificacion, dtype: int64

# %%
zona1=179
zona2=432
zona3=256
zona4=63
total=930
print(f"% Zona 1: {((zona1/total)*100)}")
print(f"% Zona 2: {((zona2/total)*100)}")
print(f"% Zona 3: {((zona3/total)*100)}")
print(f"% Zona 4: {((zona4/total)*100)}")
# Out:
# % Zona 1: 19.247311827956988
# % Zona 2: 46.45161290322581
# % Zona 3: 27.526881720430108
# % Zona 4: 6.774193548387098

# %% [markdown]
# # 14. Representa en un campo de futbol los eventos en los que participó Luis Suárez en el partido de 31 enero 2021 usando colores diferentes para marcar las diferentes zonas en las que ocurrieron.

# %%
equipo_A.drop(columns=['timestamp','team','real_position','type_id','year','month','day','clasificacion'], inplace=True)
equipo_A.head(5)
# Out:
#           x     y       player
# 44990  75.4  50.6  Luis Suárez
# 44991  76.4  48.7  Luis Suárez
# 44992  33.6   4.0  Luis Suárez
# 44993  35.1   1.3  Luis Suárez
# 44994  67.0  37.1  Luis Suárez

# %%
eventos_ls=equipo_A[equipo_A['player']=='Luis Suárez']
eventos_ls.head()
# Out:
#           x     y       player
# 44990  75.4  50.6  Luis Suárez
# 44991  76.4  48.7  Luis Suárez
# 44992  33.6   4.0  Luis Suárez
# 44993  35.1   1.3  Luis Suárez
# 44994  67.0  37.1  Luis Suárez

# %%
eventos_ls.shape
# Out:
# (40, 3)

# %%
zona1 = eventos_ls[eventos_ls['x'] <= 17]
zona2 = eventos_ls[(eventos_ls['x'] > 17) & (eventos_ls['x'] <= 50)]
zona3 = eventos_ls[(eventos_ls['x'] > 50) & (eventos_ls['x'] <= 83)]
zona4 = eventos_ls[eventos_ls['x'] > 83]

# %%
ax = pintar_campo('grey')
zona1_patch = plt.Rectangle((0, 0), 17, 100, color='yellow', alpha=0.3)
zona2_patch = plt.Rectangle((17, 0), 33, 100, color='orange', alpha=0.3)
zona3_patch = plt.Rectangle((50, 0), 33, 100, color='red', alpha=0.3)
zona4_patch = plt.Rectangle((83, 0), 17, 100, color='purple', alpha=0.3)

ax.add_patch(zona1_patch)
ax.add_patch(zona2_patch)
ax.add_patch(zona3_patch)
ax.add_patch(zona4_patch)

eventos_ls.plot(kind='scatter', x='x', y='y', color='red', ax=ax)
ax.legend()

ax.set_title("Eventos Luis Suarez", fontsize=15);
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Ejercicio con Sergio Canales

# %% [markdown]
# # 15. Usando los datos del partido seleccionado (31 enero 2021) realiza un análisis a tu elección sobre algún punto que consideres relevante. Finaliza, si puedes, el análisis con una representación gráfica

# %% [markdown]
# Sabemos el resultado del partido CADIZ 2 - 4 ATLETICO DE MADRID. Queremos saber el % de acierto en relación a todas las ocasiones creadas. De esta manera buscamos saber la "efectividad" de los equipos. El "type_id" necesario es el 15.

# %%
analisis=partido[partido['type_id']==13]
analisis
# Out:
#         type_id                timestamp     x     y         real_position  \
# 45009        13  2021-01-31T16:01:38.386  57.2  68.5               Striker
# 45018        13  2021-01-31T16:40:02.883  85.0  56.5               Striker
# 45021        13  2021-01-31T16:47:00.158  85.6  44.2               Striker
# 100033       13  2021-01-31T15:30:14.270  81.8  47.6    Central Midfielder
# 242359       13  2021-01-31T17:02:48.217  77.7  46.7  Defensive Midfielder
# 245802       13  2021-01-31T15:40:36.096  87.4  55.2               Striker
# 245819       13  2021-01-31T16:35:54.218  92.4  55.7               Striker
# 509480       13  2021-01-31T17:04:30.011  76.0  50.7      Central Defender
# 598403       13  2021-01-31T15:26:39.861  80.2  70.6                Winger
#
#                        player                team  year  month  day
# 45009             Luis Suárez  Atletico de Madrid  2021      1   31
# 45018             Luis Suárez  Atletico de Madrid  2021      1   31
# ...

# %%
goles_atm=4
goles_cd=2
lanzamientos_atm=4
lanzamientos_cd=5
print(f"% Efectividad ATM: {(goles_atm/(goles_atm+lanzamientos_atm))*100}")
print(f"% Efectividad CADIZ: {(goles_cd/(goles_cd+lanzamientos_cd))*100}")
# Out:
# % Efectividad ATM: 50.0
# % Efectividad CADIZ: 28.57142857142857

# %% [markdown]
# # Resultado del análisis.
#
# Podemos observar que en este partido ganado por el Atlético de Madrid, hubo más o menos el mismo número de disparos a puerta por parte de cada equipo.
# La efectividad del Atlético de Madrid fue del 50% , y la del Cadiz del 28%. Esta efectividad de cara a portería  parece clave a la hora de haber ganado el encuentro. Aunque habría que estudiar otras variables también para desengranar en profundidad las razones de la victoria/derrota.

# %% [markdown]
# # 16. Conclusiones: A la vista de los resultados del análisis escribe tus conclusiones sobre cada uno de los siguientes puntos:
#  -** Raking goleadores**
#
#  Máximo goleador Lionel Messi, así como los 5 primeros goleadores son todos Delanteros.
#  - **Ranking equipos con más tarjetas**
#
#  El equipo con más tarjetas recibidas es el Getafe C.F con practicamente el doble de tarjetas que el equipo con menos tarjetas (Real Madrid)
#  **- Posición media de cada jugador del ATM**
#
#  Podríamos decir que la mayoría del equipo se movió en torno al medio campo. Parece casi un planteamiento inicial del equipo. Si que identifica que el equipo se mantuvo junto durante largas fases del partido, ya fuera para sacar el balón jugador como para defender en un bloque alto o medio.
#
#  **- Porcentajes de eventos por zonas del ATM**
#  La presencia en cada zona fue:
#  % Zona 1: 19.25
# % Zona 2: 46.45
# % Zona 3: 27.53
# % Zona 4: 6.77
# Esto fue con respecto al total de eventos del Atlético de Madrid, con lo que podemos concluir que el equipo estuvo la mayor parte del tiempo en su propio campo, ya sea con balón o sin el. (Zona 1 + Zona 2).
#
# ** - Porcentajes de eventos por zonas del CAD**
# La presencia en cada zona fue:
# % Zona 1: 15.90
# % Zona 2: 31.35
# % Zona 3: 44.16
# % Zona 4: 8.58
#
# Con respecto al total de eventos del Cadiz CF, con lo que podemos concluir que el equipo tuvo un % mayor de eventos en campo contrario, ya sea con balón o sin balón.  Y pisó en mayor medida el último cuarto de campo (zona 4).
#
# Se puede ver que la mayor parte del partido se jug
# o en la zona 2 y zona 3 (medio campo). Pero que la efectividad en la zona 4 fue clave, porque ante un % de eventos parecidos. La efectividad de uno u otro de cara a portería varía en un 25% (Punto 15).
